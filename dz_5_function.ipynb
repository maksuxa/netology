# %% [markdown]
# #     Задание 1

# %%
#перечень документов
documents = [
 {'type': 'passport', 'number': '2207 876234', 'name': 'Василий Гупкин'},
 {'type': 'invoice', 'number': '11-2', 'name': 'Геннадий Покемонов'},
 {'type': 'insurance', 'number': '10006', 'name': 'Аристарх Павлов'}
]
#Директории
directories = {
 '1': ['2207 876234', '11-2'],
 '2': ['10006'],
 '3': []
}

def funkz_p():
    nomer_doc = input("Введите номер документа:")
    rezult = ("Документ не найден в базе")

    for x in documents:
        if x['number'] == nomer_doc:
            rezult = x['name']
            
    return rezult

def funkz_s():
    nomer_doc = input("Введите номер документа:")
    rezult = ("Документ не найден в базе")
    x = 1 
    values = (list(directories.values()))
    for polka in values:
        for nomer in polka:
            if nomer_doc == nomer:
                rezult = x
        x = x+1    
    return rezult
    
def funkz_i():  
    s = []
    for x in documents:
        nomer_doc = x['number']
        y = 1 
        values = (list(directories.values()))
        for polka in values:
            for nomer in polka:
                if nomer_doc == nomer:
                    rezult = y
            y = y+1    

        i = "№ " + str(x["number"]) + " Тип: " + str(x['type']) + " Владелец: " + str(x['name']) + " Полка хранения: " + str(rezult)
        s.append(i)
    return s


def funkz_ads():  
    nomer_polki = input("Введите номер полки:")
    keys = (list(directories.keys()))
    perechen_polok = ""
    for x in keys:
        perechen_polok = perechen_polok + x + ", "

    rezalt = 0    
    for x in keys:
        if nomer_polki == x:
            rezalt = 1
            print(rezalt)
    if rezalt == 1:
        #print("Такая полка уже существует. Текущий перечень полок:", perechen_polok)
        rezult = "Такая полка уже существует. Текущий перечень полок:" + str(perechen_polok)
    else:   
        directories[nomer_polki] = []
        perechen_polok = ""
        for k in directories:
            perechen_polok = perechen_polok + k + ", "
            rezult = "Полка добавлена. Текущий перечень полок:" + str(perechen_polok)
        #print("Полка добавлена. Текущий перечень полок:", perechen_polok, nomer_polki)
    
    return rezult
      
def funkz_ds():  
    nomer_polki = input("Введите номер полки:")
    keys = (list(directories.keys()))
    perechen_polok = ""
    for x in keys:
        perechen_polok = perechen_polok + x + ", "

    vspomog = 0
    for x in keys:
        if nomer_polki == x:
            vspomog = 1 
    if vspomog == 0:
        rezult = "Результат: Такой полки не существует. Текущий перечень полок:" + str(perechen_polok)
    else:
        for x in keys:
            if directories[x] != [] and nomer_polki == x:
                rezult = "Результат: На полке есть документ, удалите их перед удалением полки. Текущий перечень полок: " + str(perechen_polok)
            elif directories[x] == [] and nomer_polki == x:
                del directories[x]
                perechen = ""
                keys = (list(directories.keys()))
                for k in keys:
                    perechen = perechen + k + ", "  
                rezult = "Результат: Полка удалена.Текущий перечень полок: " + str(perechen)
                break
        
    return rezult    
        
        
comand = 0
while comand != "q": 
        print()
        comand = input(print("Введите команду:"))
        if comand == "p":
            print("Результат: ", funkz_p())   
        elif comand == "s":
            print("Результат: Документ на полке: ", funkz_s()) 
        elif comand == "i":
            lst = funkz_i()
            for l in lst:
                print(l)
        elif comand == "ads":
            print(funkz_ads())
        elif comand == "ds":
            print(funkz_ds())
# Out:
# Введите команду:
# Noneds
# Введите номер полки:2
# Результат: На полке есть документ, удалите их перед удалением полки. Текущий перечень полок: 1, 2, 3,
#
# Введите команду:
# Noneds
# Введите номер полки:1
# Результат: На полке есть документ, удалите их перед удалением полки. Текущий перечень полок: 1, 2, 3,
#
# Введите команду:
# Noneds
# Введите номер полки:7
# Результат: Такой полки не существует. Текущий перечень полок:1, 2, 3,
#
# Введите команду:
# Noneds
# Введите номер полки:3
# Результат: Полка удалена.Текущий перечень полок: 1, 2,
#
# Введите команду:
# Noneq

# %% [markdown]
# # Отдельные подпункты

# %% [markdown]
# Пункт 1. Пользователь по команде "p" может узнать владельца документа по его номеру
# Примеры работы:
# 1.
# Введите команду:
# p
#
# Введите номер документа:
# 10006
# Результат:
# Владелец документа: Аристарх Павлов
# 2.
# Введите команду:
# p
#
# Введите номер документа:
# 12345
# Результат:
# Документ не найден в базе

# %%
    s = []
    for x in documents:
        nomer_doc = x['number']
        y = 1 
        values = (list(directories.values()))
        for polka in values:
            for nomer in polka:
                if nomer_doc == nomer:
                    rezult = y
            y = y+1    
        i = "№ " + str(x["number"]) + "Тип: " + str(x['type']) + "Владелец: " + str(x['name']) + " Полка хранения:" + str(rezult)
        print(i)
# Out:
# № 2207 876234Тип: passportВладелец: Василий Гупкин Полка хранения:1
# № 11-2Тип: invoiceВладелец: Геннадий Покемонов Полка хранения:1
# № 10006Тип: insuranceВладелец: Аристарх Павлов Полка хранения:2

# %%
documents = [
 {'type': 'passport', 'number': '2207 876234', 'name': 'Василий Гупкин'},
 {'type': 'invoice', 'number': '11-2', 'name': 'Геннадий Покемонов'},
 {'type': 'insurance', 'number': '10006', 'name': 'Аристарх Павлов'}
]

nomer_doc = input("Введите номер документа:")
rezult = ("Документ не найден в базе")

for x in documents:
    if x['number'] == nomer_doc:
        rezult = x['name']
    
print("Результат: ",rezult)
# Out:
# Введите номер документа:123
# Результат:  Документ не найден в базе

# %% [markdown]
# Пункт 2. Пользователь по команде "s" может по номеру документа узнать на какой полке он хранится
# Примеры работы:
# 1.
# Введите команду:
# s
#
# Введите номер документа:
# 10006
# Результат:
# Документ хранится на полке: 2
# 2.
# Введите команду:
# p
#
# Введите номер документа:
# 12345
# Результат:
# Документ не найден в базе

# %%
directories = {
 '1': ['2207 876234', '11-2'],
 '2': ['10006'],
 '3': ['100100'],
 '4': ['10007']
}

nomer_doc = input("Введите номер документа:")
rezult = ("Документ не найден в базе")
x = 1 
values = (list(directories.values()))
for polka in values:
    for nomer in polka:
        if nomer_doc == nomer:
            rezult = x
    x = x+1    

    
print("Результат: Документ на полке: ", rezult)
# Out:
# Введите номер документа:123
# Результат: Документ на полке  Документ не найден в базе

# %% [markdown]
# Пункт 3. Пользователь по команде "l" может увидеть полную информацию по всем документам
# Пример работы:
# Введите команду:
# l
# Результат:
# №: 2207 876234, тип: passport, владелец: Василий Гупкин, полка хранения: 1
# №: 11-2, тип: invoice, владелец: Геннадий Покемонов, полка хранения: 1
# №: 10006, тип: insurance, владелец: Аристарх Павлов, полка хранения: 2

# %%
#перечень документов
documents = [
 {'type': 'passport', 'number': '2207 876234', 'name': 'Василий Гупкин'},
 {'type': 'invoice', 'number': '11-2', 'name': 'Геннадий Покемонов'},
 {'type': 'insurance', 'number': '10006', 'name': 'Аристарх Павлов'}
]
#Директории
directories = {
 '1': ['2207 876234', '11-2'],
 '2': ['10006'],
 '3': []
}


for x in documents:
    nomer_doc = x['number']
    y = 1 
    values = (list(directories.values()))
    for polka in values:
        for nomer in polka:
            if nomer_doc == nomer:
                rezult = y
        y = y+1    
    
    
    print("№ ", x["number"], "Тип: ", x['type'], "Владелец: ",x['name'], "Полка хранения:", rezult)
# Out:
# №  2207 876234 Тип:  passport Владелец:  Василий Гупкин Полка хранения 1
# №  11-2 Тип:  invoice Владелец:  Геннадий Покемонов Полка хранения 1
# №  10006 Тип:  insurance Владелец:  Аристарх Павлов Полка хранения 2

# %% [markdown]
# Пункт 4. Пользователь по команде "ads" может добавить новую полку
# Примеры работы:
# 1.
# Введите команду:
# ads
#
# Введите номер полки:
# 10
# Результат:
# Полка добавлена. Текущий перечень полок: 1, 2, 3, 10.
# 2.
# Введите команду:
# ads
#
# Введите номер полки:
# 1
# Результат:
# Такая полка уже существует. Текущий перечень полок: 1, 2, 3.

# %%
directories = {
 '1': ['2207 876234', '11-2'],
 '2': ['10006'],
 '3': []
}

directories_2 = directories.copy()

nomer_polki = input("Введите номер полки:")
keys = (list(directories_2.keys()))
perechen_polok = ""
for x in keys:
    perechen_polok = perechen_polok + x + ", "

rezalt = 0    
for x in keys:
    if nomer_polki == x:
        rezalt = 1
        print(rezalt)
if rezalt == 1:
    print("Такая полка уже существует. Текущий перечень полок:", perechen_polok)
else:   
    directories_2[nomer_polki] = []
    print("Полка добавлена. Текущий перечень полок:", perechen_polok, nomer_polki)
    

print(directories_2)
# Out:
# Введите номер полки:4
# Полка добавлена. Текущий перечень полок: 1, 2, 3,  4
# {'1': ['2207 876234', '11-2'], '2': ['10006'], '3': [], '4': []}

# %% [markdown]
# Пункт 5. Пользователь по команде "ds" может удалить существующую полку из данных (только если она пустая)
# Примеры работы:
# 1.
# Введите команду:
# ds
#
# Введите номер полки:
# 3
# Результат:
# Полка удалена. Текущий перечень полок: 1, 2.
# 2.
# Введите команду:
# ds
#
# Введите номер полки:
# 1
# Результат:
# На полке есть документа, удалите их перед удалением полки. Текущий перечень полок: 1, 2, 3.
# 3.
# Введите команду:
# ds
#
# Введите номер полки:
# 4
# Результат:
# Такой полки не существует. Текущий перечень полок: 1, 2, 3.

# %%
directories = {
 '0': [],
 '1': ['2207 876234', '11-2'],
 '2': ['10006'],
 '3': []
}

print(directories)
nomer_polki = input("Введите номер полки:")
keys = (list(directories.keys()))
perechen_polok = ""
for x in keys:
    perechen_polok = perechen_polok + x + ", "

rezult = 0
for x in keys:
    if nomer_polki == x:
        rezult = 1 
if rezult == 0:
    print("Результат: Такой полки не существует. Текущий перечень полок:", perechen_polok)
else:
    for x in keys:
        if directories[x] != [] and nomer_polki == x:
            rezult = "Результат: На полке есть документ, удалите их перед удалением полки."
        elif directories[x] == [] and nomer_polki == x:
            del directories[x]
            rezult = "Результат: Полка удалена."
            break
    
    
    perechen = ""
    keys = (list(directories.keys()))
    for k in keys:
                perechen = perechen + k + ", "    
    print(rezult)
    print("Текущий перечень полок:", perechen)
# Out:
# {'0': [], '1': ['2207 876234', '11-2'], '2': ['10006'], '3': []}
# Введите номер полки:5
# Результат: Такой полки не существует. Текущий перечень полок: 0, 1, 2, 3,
