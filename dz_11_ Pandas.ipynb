# %%
import pandas as pd

# %% [markdown]
# # Задание 1
# Скачайте с сайта https://grouplens.org/datasets/movielens/ датасет любого размера. Определите какому фильму было выставлено больше всего оценок 5.0.

# %%
ratings = pd.read_csv('/Users/maksim/Netology/material/ml-latest-small/ratings.csv')
movies = pd.read_csv('/Users/maksim/Netology/material/ml-latest-small/movies.csv')

# %%
movies_5 = ratings.query('rating == 5.0')
movies_5['movieId'].value_counts().head()
# Out:
# 318     153
# 296     123
# 356     116
# 2571    109
# 260     104
# Name: movieId, dtype: int64

# %%
movies.query('movieId == 318')
# Out:
#      movieId                             title       genres
# 277      318  Shawshank Redemption, The (1994)  Crime|Drama

# %% [markdown]
# # Задание 2
# По данным файла power.csv посчитайте суммарное потребление стран Прибалтики (Латвия, Литва и Эстония) категорий 4, 12 и 21 за период с 2005 по 2010 года. Не учитывайте в расчетах отрицательные значения quantity.

# %%
data = pd.read_csv('/Users/maksim/Netology/material/ml-latest-small/power.csv')
data.head()
# Out:
#    country  year  quantity  category
# 0  Austria  1996       5.0         1
# 1  Austria  1995      17.0         1
# 2  Belgium  2014       0.0         1
# 3  Belgium  2013       0.0         1
# 4  Belgium  2012      35.0         1

# %%
filtered_countries = data[ ((data['country']=='Lithuania') | (data['country']=='Latvia') | (data['country']=='Estonia'))
                          & ((data["category"] == 4) | (data["category"] == 12) | (data["category"] == 21)) 
                          & (data["year"] >= 2005) & (data["year"] <= 2010)
                          & (data["quantity"] >= 0) 
                         ]                        
                        
#data[ data['country'].str.contains('lit', case=False) ]['country'].unique()
filtered_countries.head()
#count_quantity 
filtered_countries['quantity'].sum()
# Out:
# 240580.0

# %% [markdown]
# # Задание 3
# Выберите страницу любого сайта с табличными данными. Импортируйте таблицы в pandas dataframe.
# Примеры страниц (необязательно брать именно эти):
# https://fortrader.org/quotes
# https://www.finanz.ru/valyuty/v-realnom-vremeni

# %%
page_url = 'https://www.finanz.ru/aktsii/realnom-vremeni-spisok/dow_jones'
df = pd.read_html(page_url, attrs = {'class': 'quote_list'}, encoding='utf-8')
#type(df)
table = df[0]
#type(table)
table
# Out:
#     Unnamed: 0  \
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15         NaN
# 16         NaN
# 17         NaN
# 18         NaN
# 19         NaN
# 20         NaN
# 21         NaN
# 22         NaN
# 23         NaN
# 24         NaN
# 25         NaN
# 26         NaN
# 27         NaN
# 28         NaN
# 29         NaN
#
#    Имя  function __handleSortingClick(componentName, fieldName, sortOrder) {  $.ajax({  url: "/Ajax/IndexShareListForRealtime/Dow_Jones",  type: "post",  data: "orderBy=" + componentName + ":" + fieldName + ":" + sortOrder,  success: function (v, x) {  $('#index-list-container').html(v);  try { trackPI(); } catch (e) { }  },  error: function () {  }  });  }  \
# 0                                                  3M
# ...
